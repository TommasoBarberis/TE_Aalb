# %% [markdown]
# # Repeated fraction of the genome
#
# Estimation of the repeated fraction of the *Aedes albopictus* based on the number of sequences in each cluster (from the results of `cd-hit-est`).

# %%
import plotly.express as px

# %%
with open("../test/cdhit/consensi.fasta.clstr", "r") as cdhit:
    lines = cdhit.readlines()

nb_list = []
nb_seq_clst = 0
nb_singleton = 0
for line in lines:
    if line.startswith(">Cluster"):
        if nb_seq_clst > 1000:
            nb_list.append(nb_seq_clst)
            nb_seq_clst = 0
        if nb_seq_clst == 1:
            nb_singleton += 1
            nb_seq_clst = 0
    else:
        nb_seq_clst += 1

# %%
fig = px.histogram(nb_list, marginal="box", title="Repeated fraction of the genome")
fig.show()
# Out:
# <div>                            <div id="c378ea13-a820-4bea-a21b-d5488f4caced" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c378ea13-a820-4bea-a21b-d5488f4caced")) {                    Plotly.newPlot(                        "c378ea13-a820-4bea-a21b-d5488f4caced",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"variable=0<br>value=%{x}<br>count=%{y}<extra></extra>","legendgroup":"0","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"0","offsetgroup":"0","orientation":"v","showlegend":true,"x":[4162,1007,1026,1515,1314,1576,1013,1290,1345,2073,7842,2553,17972,2695,1257,39611,5454,5725,8797,24475,15420,2092,2635,2600,5411,3760,19144,1221,3287,7390,1502,8100,1721,13815,52530,5207,4931,3334,2899,2441,10530,1697,3174,1247,3469,18039,5802,25968,1104,12562,10178,1078,5586,5529,2316,3568,3163,2079,1279,11127,38729,9841,1050,3013,5179,2381,1599,6260,7192,1878,1858,3371,6900,1858,8757,1613,5499,2090,1016,25939,12006,1237,3369,1499,1801,2991,7250,1543,5839,24630,2618,2624,1228,5204,2562,1784,1660,18808,2792,6691,13498,6091,12263,1006,2939,16702,5755,2367,1970,8143,4378,6173,3790,6316,1293,3791,1525,8876,1106,2498,6877,1198,1265,5541,2761,1886,4651,2053,2452,2796,16660,5045,2861,9664,2505,4975,10706,7999,13632,6044,3305,2331,1589,1046,2024,1593,12354,5235,7104,2111,3056,4733,2018,1563,2659,19984,23183,8431,6264,4303,3132,1475,5110,2882,2065,2118,1207,1018,1221,2383,4262,2766,1159,1198,1387,2164,6619,6388,1417,4847,1089,4005,2459,2597,6010,20339,1413,1739,2006,1934,2832,3203,1108,1449,1139,11437,1585,1663,1003,1834,2847,2660,11268,1415,1043,3036,14410,1113,1598,1591,1134,1647,2033,2435,2183,1109,1034,3776,2049,12979,2158,4180,3709,2345,2518,1216,1218,1019,1758,1255,2119,1584,1420,13369,1477,1135,1563,3588,1161,6060,2397,3090,3019,